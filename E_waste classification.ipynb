# %%
# !pip install tensorflow tensorflowjs matplotlib

# %%
pip install --upgrade pip

# %%
pip install --upgrade protobuf

# %%
pip install numpy
# Out:
# Collecting numpy
#   Using cached numpy-2.3.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Downloading numpy-2.3.2-cp313-cp313-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/12.8 MB 12.3 MB/s eta 0:00:01
#    -------------- ------------------------- 4.7/12.8 MB 13.2 MB/s eta 0:00:01
#    ------------------------ --------------- 7.9/12.8 MB 13.1 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.8 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 12.6 MB/s  0:00:01
# Installing collected packages: numpy
# Successfully installed numpy-2.3.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.2 which is incompatible.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import matplotlib.pyplot as plt

dataset = r"C:\Users\Acer\Desktop\EcoScrapPickup\EcoScrapPickup\dataset"

train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    shear_range=0.2,
    brightness_range=(0.8, 1.2),  
    fill_mode="nearest"
)

val_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_data = train_datagen.flow_from_directory(
    dataset,
    target_size=(224, 224),
    batch_size=32,
    class_mode="categorical",
    subset="training",
    shuffle=True,
    seed=42
)

val_data = val_datagen.flow_from_directory(
    dataset,
    target_size=(224, 224),
    batch_size=32,
    class_mode="categorical",
    subset="validation",
    shuffle=False,
    seed=42
)

base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
base_model.trainable = True  


for layer in base_model.layers[:-30]:
    layer.trainable = False

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dropout(0.3),
    Dense(128, activation="relu"),
    Dropout(0.2),
    Dense(train_data.num_classes, activation="softmax")
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

callbacks = [
    EarlyStopping(monitor="val_accuracy", patience=5, restore_best_weights=True),
    ModelCheckpoint("best_model.h5", monitor="val_accuracy", save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6)
]

history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=30,  
    callbacks=callbacks
)


plt.plot(history.history["accuracy"], label="train_acc")
plt.plot(history.history["val_accuracy"], label="val_acc")
plt.legend()
plt.title("Training vs Validation Accuracy (Fine-Tuned)")
plt.show()

model.save("ewaste_model_finetuned.h5")
# Out:
# Found 1914 images belonging to 10 classes.
# Found 478 images belonging to 10 classes.
# Epoch 1/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3697 - loss: 1.9695
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.5590 - loss: 1.4011 - val_accuracy: 0.7071 - val_loss: 0.9180 - learning_rate: 1.0000e-04
# Epoch 2/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8535 - loss: 0.5421
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.8762 - loss: 0.4437 - val_accuracy: 0.8096 - val_loss: 0.5968 - learning_rate: 1.0000e-04
# Epoch 3/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9114 - loss: 0.2957
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.9117 - loss: 0.2805 - val_accuracy: 0.8536 - val_loss: 0.5077 - learning_rate: 1.0000e-04
# Epoch 4/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9490 - loss: 0.1788
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - accuracy: 0.9493 - loss: 0.1796 - val_accuracy: 0.8808 - val_loss: 0.4325 - learning_rate: 1.0000e-04
# Epoch 5/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9594 - loss: 0.1447
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.9650 - loss: 0.1301 - val_accuracy: 0.9059 - val_loss: 0.3495 - learning_rate: 1.0000e-04
# Epoch 6/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.9791 - loss: 0.0823 - val_accuracy: 0.8766 - val_loss: 0.3620 - learning_rate: 1.0000e-04
# Epoch 7/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.9760 - loss: 0.0769 - val_accuracy: 0.8912 - val_loss: 0.3347 - learning_rate: 1.0000e-04
# Epoch 8/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.9838 - loss: 0.0601 - val_accuracy: 0.8828 - val_loss: 0.3645 - learning_rate: 1.0000e-04
# Epoch 9/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.9864 - loss: 0.0580 - val_accuracy: 0.8975 - val_loss: 0.3742 - learning_rate: 1.0000e-04
# Epoch 10/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9932 - loss: 0.0415
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.9880 - loss: 0.0506 - val_accuracy: 0.9226 - val_loss: 0.2540 - learning_rate: 1.0000e-04
# Epoch 11/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.9922 - loss: 0.0314 - val_accuracy: 0.9142 - val_loss: 0.2363 - learning_rate: 1.0000e-04
# Epoch 12/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9896 - loss: 0.0431 - val_accuracy: 0.9121 - val_loss: 0.3022 - learning_rate: 1.0000e-04
# Epoch 13/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9859 - loss: 0.0427 - val_accuracy: 0.9226 - val_loss: 0.2743 - learning_rate: 1.0000e-04
# Epoch 14/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9901 - loss: 0.0406
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.9922 - loss: 0.0364 - val_accuracy: 0.9268 - val_loss: 0.2226 - learning_rate: 1.0000e-04
# Epoch 15/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9920 - loss: 0.0345
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9927 - loss: 0.0284 - val_accuracy: 0.9351 - val_loss: 0.2047 - learning_rate: 1.0000e-04
# Epoch 16/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - accuracy: 0.9922 - loss: 0.0242 - val_accuracy: 0.9247 - val_loss: 0.2714 - learning_rate: 1.0000e-04
# Epoch 17/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - accuracy: 0.9932 - loss: 0.0226 - val_accuracy: 0.9289 - val_loss: 0.2624 - learning_rate: 1.0000e-04
# Epoch 18/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 132s 2s/step - accuracy: 0.9943 - loss: 0.0225 - val_accuracy: 0.9226 - val_loss: 0.2993 - learning_rate: 1.0000e-04
# Epoch 19/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.9948 - loss: 0.0178 - val_accuracy: 0.9268 - val_loss: 0.2893 - learning_rate: 5.0000e-05
# Epoch 20/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - accuracy: 0.9963 - loss: 0.0123 - val_accuracy: 0.9247 - val_loss: 0.2983 - learning_rate: 5.0000e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
